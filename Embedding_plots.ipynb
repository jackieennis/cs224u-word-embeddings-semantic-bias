# %% [markdown]
# ## Bias embeddings - baseline
# Here is code to make plots for the baseline metrics for gender and adjective.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
eng_embed = pd.read_excel("data/eng_tensor.xlsx")
eng_embed['Relative Female Perc'] = eng_embed['Census Female Perc'].apply(lambda x: x-(100-x))

e = eng_embed.plot(y='Cosine Distance', x='Relative Female Perc', 
       style='o', grid="true")
e.set_ylabel('Bias')
e.set_xlabel('Percent difference of women')
e.set_title("Embedding bias in English ")
e.set_ylim(-1.5, 1.5)
plt.show()
# Out:
# /Users/Olive/miniconda2/envs/nlu/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
hin_embed = pd.read_excel("data/hin_tensor.xlsx")
#make decimal value a percentage out of 100
hin_embed['Census Female Perc'] *= 100
hin_embed['Relative Female Perc'] = hin_embed['Census Female Perc'].apply(lambda x: x-(100-x))

h = hin_embed.plot(x='Relative Female Perc', y='Cosine Distance', 
               style='o', grid='true')
h.set_ylabel("Bias")
h.set_xlabel("Percent difference of women")
h.set_title("Embedding bias in Hindi ")
h.set_ylim(-5, 5)
plt.show()
# Out:
# /Users/Olive/miniconda2/envs/nlu/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
eng_adj = pd.read_excel("data/eng_tensor_adj.xlsx")
eng_adj = eng_adj.drop(columns="Unnamed: 2");
least = eng_adj.head(5)
most = eng_adj.tail(5)
comb = least.append(most)
comb
# Out:
#     Tensor Difference Adjective English  Cosine distance
# 0     tensor(-0.2910)            genius          -0.2910
# 1     tensor(-0.2890)            jovial          -0.2890
# 2     tensor(-0.2782)        gregarious          -0.2782
# 3     tensor(-0.2268)        pugnacious          -0.2268
# 4     tensor(-0.2103)         courteous          -0.2103
# 148    tensor(0.2289)          blushing           0.2289
# 149    tensor(0.2742)         beautiful           0.2742
# 150    tensor(0.3009)          gorgeous           0.3009
# 151    tensor(0.3166)           sensual           0.3166
# 152    tensor(0.4549)        voluptuous           0.4549

# %%
engadjplot = least.plot.bar(x='Adjective English', y='Cosine distance', rot=0)
engadjplot.set_ylabel('Bias')
engadjplot.set_title('Top 5 Male adjectives')
engadjplot2 = most.plot.bar(x='Adjective English', y='Cosine distance', rot=0)
engadjplot2.set_ylabel('Bias')
engadjplot2.set_title('Top 5 Female adjectives')
plt.show()

# %%
hin_adj = pd.read_excel("data/hin_adj_fixed.xlsx")
hin_adj = hin_adj.drop(columns="Unnamed: 3")
h_least = hin_adj.head(5)
h_most = hin_adj.tail(5)
hin_adj
# Out:
#   Tensor Difference Adjective Hindi Adjective English  Cosine distance
# 0  tensor(-16.6688)        नमक हराम       treacherous         -16.6688
# 1   tensor(-2.5926)         ईमानदार            honest          -2.5926
# 2   tensor(-2.3548)           धूर्त               sly          -2.3548
# 3   tensor(-2.3329)          अशिष्ट              rude          -2.3329
# 4   tensor(-2.1453)         मेहरबान              kind          -2.1453
# 5    tensor(0.9955)            भव्य          gorgeous           0.9955
# 6    tensor(1.3151)         असामयिक        precocious           1.3151
# 7    tensor(1.3651)       प्रगतिशील       progressive           1.3651
# 8    tensor(1.9447)           कामुक           sensual           1.9447
# 9    tensor(1.9447)           कामुक        voluptuous           1.9447

# %%
hinadjplot = h_least.plot.bar(x='Adjective English', y='Cosine distance', rot=0)
hinadjplot.set_ylabel('Bias')
hinadjplot.set_title('Top 5 Male adjectives')
hinadjplot2 = h_most.plot.bar(x='Adjective English', y='Cosine distance', rot=0)
hinadjplot2.set_ylabel('Bias')
hinadjplot2.set_title('Top 5 Female adjectives')
plt.show()
